# %% [raw]
# jovyan@e6db64941a67:~$ cat /usr/local/bin/voila.start.sh
# #!/bin/bash
# mkdir -p ~/voila
# voila --Voila.ip=0.0.0.0 --port=$VOILA_PORT --no-browser --classic-tree \
#     --VoilaConfiguration.file_allowlist="['.*']" \
#     ~/voila > /dev/null 2>&1 &

# %% [raw]
# !start /b voila --no-browser --port=8867 --classic-tree --VoilaConfiguration.file_allowlist="['.*']"

# %% [raw]
# !start /b voila --no-browser --port=8867

# %% [raw]
# !taskkill /F /IM voila.exe

# %% [raw]
# %%cmd
# mkdir "%USERPROFILE%\voila"
# dir

# %% [raw]
# %%cmd
# cd C:\Users\d93376\voila
# start /b voila --no-browser --port=8867

# %% [raw]
# %conda install -c conda-forge jupyter_contrib_nbextensions

# %% [raw]
# !conda install -c conda-forge "setuptools<82" -y

# %% [raw]
# !conda install -c conda-forge "tinycss2<1.5" -y

# %% [raw]
# !jupyter contrib nbextension install --sys-prefix

# %%
# %run github_uploader.py c:\Users\d93376\notebooks\EUCLIDE\tools.ipynb
# Out:
# ---------------------------------------------------------------------------
# UnknownObjectException                    Traceback (most recent call last)
# File ~\notebooks\EUCLIDE\github_uploader.py:49
#      46 if __name__ == "__main__":
#      47     if len(sys.argv) > 1:
#      48         # Библиотека PyGithub сама закодирует в base64 при отправке
# ---> 49         upload_file(sys.argv[1])
#      50     else:
#      51         print("Файл не выбран.")
#
# File ~\notebooks\EUCLIDE\github_uploader.py:22, in upload_file(file_path)
#      20 # Инициализация GitHub
#      21 g = Github(auth=Auth.Token(TOKEN))
# ---> 22 repo = g.get_repo(REPO_NAME)
#      24 file_name = os.path.basename(file_path)
#      26 try:
#      27     # Проверяем, есть ли уже такой файл в репозитории
#
# File ~\miniconda3\envs\voila_env\lib\site-packages\github\MainClass.py:490, in Github.get_repo(self, full_name_or_id, lazy)
# ...
